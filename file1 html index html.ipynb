# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>MAVEX Cloud Compute Utility — Pay Only When You Need Power</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>

    <header>
        <div class="brand">MAVEX<span class="dot">.</span></div>
        <h1>Your Cloud Power, Unlocked.</h1>
        <p>The first Hybrid OS monitor built for on-demand AI/ML, secured by TPM.</p>
        <button id="cta-button" onclick="document.getElementById('simulator').scrollIntoView({ behavior: 'smooth' });">Launch Live Simulator</button>
    </header>

    <section id="simulator" class="simulator-section">
        <h2>Experience 720p@60fps Compute Power</h2>
        <p>Watch how MAVEX instantly delivers GPU acceleration and protects your credits in real-time.</p>

        <div class="simulator-container">
            <div id="stream-window" class="stream-window">
                
                <div class="stream-placeholder">
                    <img src="https://via.placeholder.com/1280x720/0f172a/1fb6ff?text=MAVEX+Cloud+Desktop+-+720p%4060fps+Streaming+Active" alt="Simulated Cloud Desktop">
                </div>
                
                <div id="hud-overlay">
                    <div class="status-line">
                        <span class="label">TIER:</span>
                        <span id="tier-display">AI_DEVELOPER</span>
                    </div>
                    <div class="status-line">
                        <span class="label">RATE:</span>
                        <span id="rate-display">0.25 CREDITS/S</span>
                    </div>
                    <div class="status-line balance-line">
                        <span class="label">BALANCE:</span>
                        <span id="credits-display" class="balance-value">54000.00</span>
                    </div>
                </div>

                <div id="control-panel">
                    <button id="start-btn" onclick="startSimulator()" class="control-btn start-btn">START CLOUD POWER</button>
                    <button id="stop-btn" onclick="stopSimulator()" class="control-btn stop-btn disabled">STOP</button>
                </div>
            </div>
            
            <div id="lockout-screen">
                <h1>SESSION TERMINATED</h1>
                <p>Your MAVEX compute credits have been exhausted. Please recharge your balance to restore the cloud desktop.</p>
                <a href="#"><button class="control-btn recharge-btn">RECHARGE CREDITS</button></a>
            </div>
        </div>
    </section>

    <footer>
        <div class="cta-box">
            <h3>Ready to own your compute future?</h3>
            <p>Join the pilot program and reserve your MAVEX Smart Monitor.</p>
            <button class="control-btn pre-order-btn">Pre-Order Now 🚀</button>
        </div>
        <p class="copyright">&copy; 2025 Mavex Compute Utility. All rights reserved.</p>
    </footer>

    <script src="demo.js"></script>
</body>
</html>
